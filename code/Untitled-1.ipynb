# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
labels= [
          "2018-01",
          "2018-02",
          "2018-03",
          "2018-04",
          "2018-05",
          "2018-06",
          "2018-07",
          "2018-08",
          "2018-09",
          "2018-10",
          "2018-11",
          "2018-12",
          "2019-01",
          "2019-02",
          "2019-03",
          "2019-04",
          "2019-05",
          "2019-06",
          "2019-07",
          "2019-08",
          "2019-09",
          "2019-10",
          "2019-11",
          "2019-12",
          "2020-01",
          "2020-02",
          "2020-03",
          "2020-04",
          "2020-05",
          "2020-06",
          "2020-07",
          "2020-08",
          "2020-09",
          "2020-10",
          "2020-11",
          "2020-12",
          "2021-01",
          "2021-02",
          "2021-03",
          "2021-04",
          "2021-05",
          "2021-06",
          "2021-07",
          "2021-08",
          "2021-09",
          "2021-10",
          "2021-11",
          "2021-12",
          "2022-01",
          "2022-02",
          "2022-03",
          "2022-04",
          "2022-05",
          "2022-06",
          "2022-07",
          "2022-08",
          "2022-09",
          "2022-10",
          "2022-11",
          "2022-12",
        ]
value= [
              1480, 999, 1529, 1320, 1795, 1358, 1920, 1452, 1129, 1470, 1390,
              2847, 1451, 886, 1431, 1286, 1465, 1382, 1909, 1269, 1103, 1328,
              1281, 2892, 1348, 1426, 2043, 1683, 1373, 1477, 1947, 1533, 1408,
              1423, 1352, 3286, 1596, 1239, 1916, 1549, 1593, 1763, 2152, 2416,
              1812, 1750, 1790, 3897, 2029, 1194, 1936, 1801, 1681, 1727, 2504,
              1851, 1590, 1690, 1667, 3226,
            ]

df = pd.DataFrame({"labels": labels, "value": value})
df["labels"] = pd.to_datetime(df["labels"])
fig, ax = plt.subplots(figsize=(10, 4))
sns.lineplot(data=df, x="labels", y="value", ax=ax)
plt.xticks(rotation=90)
ax.set_xlabel("Thời gian")
ax.set_ylabel("Số lượng văn bản")
# export file
# bigger font size
plt.rcParams.update({"font.size": 15})
plt.savefig("lineplot.svg", bbox_inches="tight")
plt.show()
# Out:
# c:\Users\ngoph\scoop\apps\anaconda3\current\App\envs\me\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\ngoph\scoop\apps\anaconda3\current\App\envs\me\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\ngoph\scoop\apps\anaconda3\current\App\envs\me\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\ngoph\scoop\apps\anaconda3\current\App\envs\me\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
labels= [
1924, 1926, 1929, 1930, 1944, 1945, 1946, 1947, 1948, 1949, 1950,
1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961,
1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972,
1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983,
1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994,
1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005,
2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016,
2017, 2018, 2019, 2020, 2021, 2022, 
]
data=[
2, 1, 2, 1, 1, 120, 320, 111, 129, 116, 131, 50, 30, 34, 6, 49,
238, 359, 305, 362, 277, 347, 289, 272, 329, 112, 125, 82, 98,
103, 99, 104, 79, 86, 159, 129, 110, 348, 316, 307, 226, 306, 303,
255, 273, 388, 315, 311, 331, 384, 480, 520, 637, 612, 962, 1094,
1131, 1448, 1936, 2462, 2347, 2621, 2899, 4215, 4766, 4908, 8054,
9568, 10912, 10583, 10287, 11434, 12593, 16164, 17307, 16833,
22009, 18992, 18689, 17683, 20299, 23473, 22896,
]


df = pd.DataFrame({"labels": labels, "value": data})

fig, ax = plt.subplots(figsize=(10, 4))
sns.lineplot(data=df, x="labels", y="value", ax=ax)
plt.xticks(rotation=90)
ax.set_xlabel("Thời gian")
ax.set_ylabel("Số lượng văn bản")
# export file
# bigger font size
plt.rcParams.update({"font.size": 15})
plt.savefig("lineplot2.svg", bbox_inches="tight")

# more x grid lines
ax.xaxis.set_major_locator(plt.MaxNLocator(20))

plt.show()
# Out:
# c:\Users\ngoph\scoop\apps\anaconda3\current\App\envs\me\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\ngoph\scoop\apps\anaconda3\current\App\envs\me\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\ngoph\scoop\apps\anaconda3\current\App\envs\me\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\ngoph\scoop\apps\anaconda3\current\App\envs\me\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
